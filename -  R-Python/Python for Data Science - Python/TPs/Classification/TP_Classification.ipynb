# %% [markdown]
# # Classification
#
# On se propose d'aapliquer plusieurs algorithmes de classification sur un ensemble de données

# %%
# Classification template

# Charger les modules numpy, matplotlib et pandas


# Chargement des données
dataset = # utiliser une commande pandas pour charger les données
X = # charger ici les 3eme et 4eme colonnes
y = # charger ici la dernière colonne


# Prospection préliminaire
# Tracer l'histogramme de la variable age
# Tracer l'histogramme de la variable Estimated Salary
# Tracer l'histogramme de la variable purchased

# Tracer Age en fonction de Purchased
# Tracer EstimatedSalary en fonction de Purchased
# Tracer EstimatedSalary en fonction de Age


# Splitting the dataset into the Training set and Test set
# ici appeler la fonction permettant la réalisation du split

# il faut que le ratio soit 3/4 1/4 avec un random state de 0
# Commenter cette étape?
# Donner le type de la sortie de la fonction train_test_split
XXXXXXXXXXXXXXX = train_test_split(XXXXXXXX)

# Feature Scaling
# Commenter cette étape
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)



# Fitting classifier to the Training set
# Utiliser le fichier de cours de la dernière séance
# Appliquer les différents modèles de classification
# la régression logistique logistique regression
# KNN (K Nearest Neighbors)
# Support Vector Machine SVM
# Kernel SVM
# Naives Bayes
# Decision Tree Classification
# Random Forest Classification



# Create your classifier here

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Visualising the Training set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)

    

    
# Ajouter le titre suivant "Training set"
# Ajouter "Age" sur l'axe des x
# Ajouter "Estimated Salary" sur l'axe des y
plt.legend()
plt.show()


# Visualising the Test set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
# Ajouter le titre suivant "Training set"
# Ajouter "Age" sur l'axe des x
# Ajouter "Estimated Salary" sur l'axe des y


plt.legend()
plt.show()



# Making the Confusion Matrix
# Afin de quantifier les performances du modèle
# on utilise la matrice de confusion
# Chercher dans les métriques de sklearn 
# la fonction confusion matrix


# la ligne de code ici

cm = confusion_matrix(y_test, y_pred)


# Calculer le pourcentage de réussite
# Calculer le pourcentage d'échec
